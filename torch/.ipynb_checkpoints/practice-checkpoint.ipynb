# %%
import torch

# %%
t = torch.FloatTensor([0., 1., 2., 3., 4., 5.])

print(t)
print(t.dim())
print(t.shape)
print(t.size())
# Out:
# tensor([0., 1., 2., 3., 4., 5.])
# 1
# torch.Size([6])
# torch.Size([6])

# %% [markdown]
# # 선형회귀 구현

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ### x, y dataset define

# %%
torch.manual_seed(1)

x_train = torch.FloatTensor([[1], [2], [3]])
y_train = torch.FloatTensor([[2], [4], [6]])

print("x_train => \n",x_train)
print("y_train => \n",y_train)
# Out:
# x_train =>
#  tensor([[1.],
#         [2.],
#         [3.]])
# y_train =>
#  tensor([[2.],
#         [4.],
#         [6.]])

# %% [markdown]
# ### Weight, bias define

# %%
W = torch.zeros(1, requires_grad=True)
# requires_grad=True는 train을 통해 값이 계속 변하는 변수임을 의미함
print(W)

b = torch.zeros(1, requires_grad=True)
print(b)

# y = Wx + b  ==>   y = 0 * x + 0 인 상태
# Out:
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)

# %% [markdown]
# ### loss function define
# ###### H(x) = Wx + b
# ###### cost(W,b)=1/n* n∑i=1 [y(i)−H(x(i))]2
# ###### 평균 제곱 오차 MSE

# %%
hypothesis = x_train * W + b
print(hypothesis)

cost = torch.mean((hypothesis - y_train) ** 2)
print(cost)
# Out:
# tensor([[0.],
#         [0.],
#         [0.]], grad_fn=<AddBackward0>)
# tensor(18.6667, grad_fn=<MeanBackward0>)

# %% [markdown]
# ### optimizer function define

# %%
optimizer = optim.SGD([W,b], lr=0.01)
print(optimizer)
print(W)
print(b)
# gradient를 0으로 초기화
optimizer.zero_grad()
print(optimizer)
print(W)
print(b)
# cost function을 미분하여 gradient 계산
print(cost)
cost.backward()
print(cost)
print(W)
print(b)

# W와 b 업데이트
optimizer.step()
print(optimizer)
print(W)
print(b)
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.01
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.01
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# tensor(18.6667, grad_fn=<MeanBackward0>)
# tensor(18.6667, grad_fn=<MeanBackward0>)
# tensor([0.], requires_grad=True)
# tensor([0.], requires_grad=True)
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.01
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# tensor([0.1867], requires_grad=True)
# tensor([0.0800], requires_grad=True)

# %% [markdown]
# # training

# %%
x_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[2],[4],[6]])

W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

optimizer = optim.SGD([W, b], lr = 0.01)

epochs = 2000

for epoch in range(epochs + 1) :
    
    hypothesis = x_train * W + b
    
    cost = torch.mean((hypothesis - y_train) ** 2)

#     optimizer.zero_grad()
    grad_hypo = 2 * (hypothesis - y_train)
    print("grad_hypo : ",grad_hypo)
    grad_w = x_train * grad_hypo + b
    print("grad_w : ",grad_w)
    grad_b = hypothesis - x_train * grad_w
    
    W = W - 0.01 * grad_w
    b = b - 0.01 * grad_b
    
    #cost.backward()
    #optimizer.step()
    
    # .item()으로 tensor 형식의 변수에서 값만 가져올 수 있음
    if epoch % 100 == 0 :
#         print(W)
#         print(b)
#         print(cost)
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            epoch, epochs, W.sum().item(), b.sum().item(), cost.item()))
# Out:
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.],
#         [-16.],
#         [-36.]], grad_fn=<AddBackward0>)
# Epoch    0/2000 W: 0.560, b: -1.440 Cost: 18.666666
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.0400],
#         [-16.3200],
#         [-37.0800]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.0804],
#         [-16.6464],
#         [-38.1924]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.1212],
#         [-16.9793],
#         [-39.3382]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.1624],
#         [-17.3189],
#         [-40.5183]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.2040],
#         [-17.6653],
#         [-41.7339]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.2461],
#         [-18.0186],
#         [-42.9859]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.2885],
#         [-18.3790],
#         [-44.2755]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.3314],
#         [-18.7465],
#         [-45.6037]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.3747],
#         [-19.1215],
#         [-46.9718]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.4185],
#         [-19.5039],
#         [-48.3810]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.4627],
#         [-19.8940],
#         [-49.8324]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.5073],
#         [-20.2919],
#         [-51.3274]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.5524],
#         [-20.6977],
#         [-52.8672]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.5979],
#         [-21.1117],
#         [-54.4532]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.6439],
#         [-21.5339],
#         [-56.0868]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.6903],
#         [-21.9646],
#         [-57.7694]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.7372],
#         [-22.4039],
#         [-59.5025]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.7846],
#         [-22.8519],
#         [-61.2876]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.8324],
#         [-23.3090],
#         [-63.1262]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.8808],
#         [-23.7752],
#         [-65.0200]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.9296],
#         [-24.2507],
#         [-66.9706]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -4.9789],
#         [-24.7357],
#         [-68.9798]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.0287],
#         [-25.2304],
#         [-71.0492]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.0789],
#         [-25.7350],
#         [-73.1806]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.1297],
#         [-26.2497],
#         [-75.3760]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.1810],
#         [-26.7747],
#         [-77.6373]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.2328],
#         [-27.3102],
#         [-79.9665]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.2852],
#         [-27.8564],
#         [-82.3655]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.3380],
#         [-28.4135],
#         [-84.8364]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.3914],
#         [-28.9818],
#         [-87.3815]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.4453],
#         [-29.5614],
#         [-90.0030]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.4998],
#         [-30.1526],
#         [-92.7030]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.5548],
#         [-30.7557],
#         [-95.4841]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -5.6103],
#         [-31.3708],
#         [-98.3486]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -5.6664],
#         [ -31.9982],
#         [-101.2991]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -5.7231],
#         [ -32.6382],
#         [-104.3381]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -5.7803],
#         [ -33.2910],
#         [-107.4682]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -5.8381],
#         [ -33.9568],
#         [-110.6923]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -5.8965],
#         [ -34.6359],
#         [-114.0131]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -5.9555],
#         [ -35.3286],
#         [-117.4334]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.0150],
#         [ -36.0352],
#         [-120.9565]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.0752],
#         [ -36.7559],
#         [-124.5852]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.1359],
#         [ -37.4910],
#         [-128.3228]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.1973],
#         [ -38.2409],
#         [-132.1724]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.2592],
#         [ -39.0057],
#         [-136.1376]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.3218],
#         [ -39.7858],
#         [-140.2217]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.3851],
#         [ -40.5815],
#         [-144.4283]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.4489],
#         [ -41.3931],
#         [-148.7612]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.5134],
#         [ -42.2210],
#         [-153.2241]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.5785],
#         [ -43.0654],
#         [-157.8207]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.6443],
#         [ -43.9267],
#         [-162.5553]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.7108],
#         [ -44.8053],
#         [-167.4320]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.7779],
#         [ -45.7014],
#         [-172.4550]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.8456],
#         [ -46.6154],
#         [-177.6287]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.9141],
#         [ -47.5477],
#         [-182.9574]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -6.9832],
#         [ -48.4986],
#         [-188.4462]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.0531],
#         [ -49.4686],
#         [-194.0995]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.1236],
#         [ -50.4580],
#         [-199.9225]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.1948],
#         [ -51.4672],
#         [-205.9203]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.2668],
#         [ -52.4965],
#         [-212.0979]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.3395],
#         [ -53.5464],
#         [-218.4608]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.4128],
#         [ -54.6174],
#         [-225.0145]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.4870],
#         [ -55.7097],
#         [-231.7649]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.5618],
#         [ -56.8239],
#         [-238.7178]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.6375],
#         [ -57.9604],
#         [-245.8794]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.7138],
#         [ -59.1196],
#         [-253.2558]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0000]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.7910],
#         [ -60.3020],
#         [-260.8535]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.8689],
#         [ -61.5080],
#         [-268.6791]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -7.9476],
#         [ -62.7382],
#         [-276.7395]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.0271],
#         [ -63.9929],
#         [-285.0417]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.1073],
#         [ -65.2728],
#         [-293.5930]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.1884],
#         [ -66.5782],
#         [-302.4008]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.2703],
#         [ -67.9098],
#         [-311.4728]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.3530],
#         [ -69.2680],
#         [-320.8170]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.4365],
#         [ -70.6534],
#         [-330.4415]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.5209],
#         [ -72.0664],
#         [-340.3547]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.6061],
#         [ -73.5078],
#         [-350.5652]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.6921],
#         [ -74.9779],
#         [-361.0823]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.7791],
#         [ -76.4775],
#         [-371.9146]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.8669],
#         [ -78.0070],
#         [-383.0720]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -8.9555],
#         [ -79.5672],
#         [-394.5642]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.0451],
#         [ -81.1585],
#         [-406.4011]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.1355],
#         [ -82.7817],
#         [-418.5933]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.2269],
#         [ -84.4373],
#         [-431.1511]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0001]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.3192],
#         [ -86.1261],
#         [-444.0858]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0001]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.4124],
#         [ -87.8486],
#         [-457.4084]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0001]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.5065],
#         [ -89.6055],
#         [-471.1307]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0001]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.6015],
#         [ -91.3977],
#         [-485.2646]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.6976],
#         [ -93.2256],
#         [-499.8223]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.7945],
#         [ -95.0901],
#         [-514.8168]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.8925],
#         [ -96.9919],
#         [-530.2615]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -9.9914],
#         [ -98.9318],
#         [-546.1693]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.0913],
#         [-100.9104],
#         [-562.5544]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.1922],
#         [-102.9286],
#         [-579.4310]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.2942],
#         [-104.9872],
#         [-596.8140]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.3971],
#         [-107.0869],
#         [-614.7184]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.5011],
#         [-109.2287],
#         [-633.1599]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.6061],
#         [-111.4132],
#         [-652.1544]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.7121],
#         [-113.6415],
#         [-671.7194]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.8193],
#         [-115.9143],
#         [-691.8710]], grad_fn=<AddBackward0>)
# Epoch  100/2000 W: 283.586, b: -785.787 Cost: 18.666666
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -10.9274],
#         [-118.2326],
#         [-712.6267]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.0367],
#         [-120.5973],
#         [-734.0055]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.1471],
#         [-123.0092],
#         [-756.0253]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.2586],
#         [-125.4694],
#         [-778.7064]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.3711],
#         [-127.9788],
#         [-802.0676]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.4849],
#         [-130.5384],
#         [-826.1293]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.5997],
#         [-133.1491],
#         [-850.9131]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.7157],
#         [-135.8121],
#         [-876.4406]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.8329],
#         [-138.5284],
#         [-902.7338]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -11.9512],
#         [-141.2989],
#         [-929.8158]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -12.0707],
#         [-144.1249],
#         [-957.7106]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9998]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[ -12.1914],
#         [-147.0074],
#         [-986.4416]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -12.3133],
#         [ -149.9475],
#         [-1016.0352]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9999]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -12.4365],
#         [ -152.9465],
#         [-1046.5164]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -12.5608],
#         [ -156.0054],
#         [-1077.9121]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -12.6864],
#         [ -159.1255],
#         [-1110.2495]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -12.8133],
#         [ -162.3080],
#         [-1143.5570]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -12.9414],
#         [ -165.5542],
#         [-1177.8638]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.0708],
#         [ -168.8653],
#         [-1213.2004]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.2015],
#         [ -172.2426],
#         [-1249.5964]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.3336],
#         [ -175.6874],
#         [-1287.0844]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.4669],
#         [ -179.2012],
#         [-1325.6969]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.6016],
#         [ -182.7852],
#         [-1365.4678]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.7376],
#         [ -186.4409],
#         [-1406.4318]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -13.8750],
#         [ -190.1697],
#         [-1448.6248]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.0137],
#         [ -193.9731],
#         [-1492.0835]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.1538],
#         [ -197.8526],
#         [-1536.8459]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.2954],
#         [ -201.8096],
#         [-1582.9513]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.4383],
#         [ -205.8458],
#         [-1630.4398]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0002]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.5827],
#         [ -209.9627],
#         [-1679.3530]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.7285],
#         [ -214.1620],
#         [-1729.7344]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -14.8758],
#         [ -218.4452],
#         [-1781.6265]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.0246],
#         [ -222.8141],
#         [-1835.0737]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.1748],
#         [ -227.2704],
#         [-1890.1274]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.3266],
#         [ -231.8158],
#         [-1946.8313]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.4799],
#         [ -236.4521],
#         [-2005.2362]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.6347],
#         [ -241.1812],
#         [-2065.3933]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.7910],
#         [ -246.0048],
#         [-2127.3552]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -15.9489],
#         [ -250.9249],
#         [-2191.1758]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -16.1084],
#         [ -255.9434],
#         [-2256.9126]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -16.2695],
#         [ -261.0623],
#         [-2324.6184]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -16.4322],
#         [ -266.2835],
#         [-2394.3569]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -16.5965],
#         [ -271.6092],
#         [-2466.1892]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -16.7625],
#         [ -277.0414],
#         [-2540.1748]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -16.9301],
#         [ -282.5822],
#         [-2616.3801]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -17.0994],
#         [ -288.2338],
#         [-2694.8716]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -17.2704],
#         [ -293.9985],
#         [-2775.7178]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -17.4431],
#         [ -299.8785],
#         [-2858.9893]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -17.6175],
#         [ -305.8760],
#         [-2944.7590]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -17.7937],
#         [ -311.9936],
#         [-3033.1018]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -17.9716],
#         [ -318.2334],
#         [-3124.0947]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -18.1513],
#         [ -324.5981],
#         [-3217.8176]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0005]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -18.3329],
#         [ -331.0901],
#         [-3314.3506]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -18.5162],
#         [ -337.7119],
#         [-3413.7795]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -18.7013],
#         [ -344.4661],
#         [-3516.1929]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9995]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -18.8884],
#         [ -351.3554],
#         [-3621.6772]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9995]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -19.0772],
#         [ -358.3825],
#         [-3730.3276]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -19.2680],
#         [ -365.5502],
#         [-3842.2390]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -19.4607],
#         [ -372.8612],
#         [-3957.5061]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9995]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -19.6553],
#         [ -380.3184],
#         [-4076.2297]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-11.9990]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -19.8519],
#         [ -387.9247],
#         [-4198.5151]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -20.0504],
#         [ -395.6832],
#         [-4324.4736]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -20.2509],
#         [ -403.5969],
#         [-4454.2080]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -20.4534],
#         [ -411.6688],
#         [-4587.8374]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -20.6579],
#         [ -419.9022],
#         [-4725.4697]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -20.8645],
#         [ -428.3002],
#         [-4867.2368]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -21.0731],
#         [ -436.8662],
#         [-5013.2539]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -21.2839],
#         [ -445.6036],
#         [-5163.6484]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -21.4967],
#         [ -454.5157],
#         [-5318.5610]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -21.7117],
#         [ -463.6060],
#         [-5478.1177]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0020]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -21.9288],
#         [ -472.8781],
#         [-5642.4644]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0020]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -22.1481],
#         [ -482.3356],
#         [-5811.7383]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -22.3696],
#         [ -491.9823],
#         [-5986.0874]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -22.5933],
#         [ -501.8220],
#         [-6165.6699]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -22.8192],
#         [ -511.8584],
#         [-6350.6401]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -23.0474],
#         [ -522.0956],
#         [-6541.1592]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -23.2779],
#         [ -532.5375],
#         [-6737.3940]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -23.5106],
#         [ -543.1883],
#         [-6939.5127]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -23.7458],
#         [ -554.0521],
#         [-7147.7012]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -23.9832],
#         [ -565.1331],
#         [-7362.1323]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -24.2230],
#         [ -576.4358],
#         [-7582.9932]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0010]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -24.4653],
#         [ -587.9645],
#         [-7810.4858]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -24.7099],
#         [ -599.7238],
#         [-8044.7974]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -24.9570],
#         [ -611.7182],
#         [-8286.1416]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -25.2066],
#         [ -623.9526],
#         [-8534.7256]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0020]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -25.4587],
#         [ -636.4316],
#         [-8790.7734]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0020]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -25.7132],
#         [ -649.1603],
#         [-9054.4971]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0020]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -25.9704],
#         [ -662.1435],
#         [-9326.1318]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -26.2301],
#         [ -675.3864],
#         [-9605.9219]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[  -26.4924],
#         [ -688.8941],
#         [-9894.0996]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -26.7573],
#         [  -702.6720],
#         [-10190.9229]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -27.0249],
#         [  -716.7255],
#         [-10496.6504]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -27.2951],
#         [  -731.0600],
#         [-10811.5498]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -27.5681],
#         [  -745.6812],
#         [-11135.8965]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -27.8438],
#         [  -760.5948],
#         [-11469.9795]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -28.1222],
#         [  -775.8068],
#         [-11814.0791]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -28.4034],
#         [  -791.3229],
#         [-12168.4951]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -28.6875],
#         [  -807.1494],
#         [-12533.5557]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -28.9743],
#         [  -823.2924],
#         [-12909.5625]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -29.2641],
#         [  -839.7582],
#         [-13296.8496]], grad_fn=<AddBackward0>)
# Epoch  200/2000 W: 4999.078, b: -14525.848 Cost: 18.678389
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -29.5567],
#         [  -856.5533],
#         [-13695.7549]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -29.8523],
#         [  -873.6844],
#         [-14106.6338]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -30.1508],
#         [  -891.1581],
#         [-14529.8330]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0059]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -30.4523],
#         [  -908.9813],
#         [-14965.7217]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -30.7568],
#         [  -927.1609],
#         [-15414.6992]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -31.0644],
#         [  -945.7041],
#         [-15877.1406]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -31.3750],
#         [  -964.6182],
#         [-16353.4551]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -31.6888],
#         [  -983.9105],
#         [-16844.0586]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -32.0057],
#         [ -1003.5887],
#         [-17349.3809]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -32.3257],
#         [ -1023.6605],
#         [-17869.8613]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -32.6490],
#         [ -1044.1338],
#         [-18405.9570]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0039]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -32.9755],
#         [ -1065.0165],
#         [-18958.1230]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -33.3052],
#         [ -1086.3168],
#         [-19526.8789]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -33.6383],
#         [ -1108.0431],
#         [-20112.6855]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -33.9747],
#         [ -1130.2040],
#         [-20716.0664]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -34.3144],
#         [ -1152.8081],
#         [-21337.5605]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -34.6576],
#         [ -1175.8643],
#         [-21977.6875]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -35.0042],
#         [ -1199.3816],
#         [-22637.0176]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -35.3542],
#         [ -1223.3693],
#         [-23316.1289]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0156]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -35.7077],
#         [ -1247.8367],
#         [-24015.6250]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0156]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -36.0648],
#         [ -1272.7935],
#         [-24736.0938]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -36.4255],
#         [ -1298.2493],
#         [-25478.1523]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -36.7897],
#         [ -1324.2142],
#         [-26242.4961]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -37.1576],
#         [ -1350.6985],
#         [-27029.7832]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -37.5292],
#         [ -1377.7124],
#         [-27840.6641]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -37.9045],
#         [ -1405.2666],
#         [-28675.8965]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0156]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -38.2835],
#         [ -1433.3719],
#         [-29536.1855]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -38.6664],
#         [ -1462.0394],
#         [-30422.2598]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -39.0530],
#         [ -1491.2803],
#         [-31334.9277]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0117]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -39.4436],
#         [ -1521.1058],
#         [-32274.9746]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -39.8380],
#         [ -1551.5280],
#         [-33243.2109]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -40.2364],
#         [ -1582.5585],
#         [-34240.5078]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -40.6387],
#         [ -1614.2096],
#         [-35267.7227]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -41.0451],
#         [ -1646.4938],
#         [-36325.7539]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -41.4556],
#         [ -1679.4237],
#         [-37415.5273]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -41.8701],
#         [ -1713.0122],
#         [-38537.9922]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -42.2888],
#         [ -1747.2725],
#         [-39694.1328]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -42.7117],
#         [ -1782.2179],
#         [-40884.9570]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -43.1388],
#         [ -1817.8623],
#         [-42111.5039]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[   -43.5702],
#         [ -1854.2196],
#         [-43374.8242]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-4.4006e+01],
#         [-1.8913e+03],
#         [-4.4676e+04]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-4.4446e+01],
#         [-1.9291e+03],
#         [-4.6016e+04]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-4.4890e+01],
#         [-1.9677e+03],
#         [-4.7397e+04]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.0000],
#         [ -8.0000],
#         [-12.0078]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-4.5339e+01],
#         [-2.0071e+03],
#         [-4.8819e+04]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
# ...
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.1068e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.1670e+08],
#         [-5.5239e+17],
#         [-1.7470e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.1068e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.2486e+08],
#         [-5.6344e+17],
#         [-1.7994e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.1068e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.3311e+08],
#         [-5.7471e+17],
#         [-1.8534e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.4144e+08],
#         [-5.8621e+17],
#         [-1.9090e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.4986e+08],
#         [-5.9793e+17],
#         [-1.9662e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.5836e+08],
#         [-6.0989e+17],
#         [-2.0252e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.6694e+08],
#         [-6.2209e+17],
#         [-2.0860e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.7561e+08],
#         [-6.3453e+17],
#         [-2.1485e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-3.6893e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.8437e+08],
#         [-6.4722e+17],
#         [-2.2130e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-3.6893e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-8.9321e+08],
#         [-6.6016e+17],
#         [-2.2794e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-3.6893e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.0214e+08],
#         [-6.7337e+17],
#         [-2.3478e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.1116e+08],
#         [-6.8683e+17],
#         [-2.4182e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.2027e+08],
#         [-7.0057e+17],
#         [-2.4907e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.2948e+08],
#         [-7.1458e+17],
#         [-2.5655e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.3877e+08],
#         [-7.2887e+17],
#         [-2.6424e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-3.6893e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.4816e+08],
#         [-7.4345e+17],
#         [-2.7217e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-3.6893e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.5764e+08],
#         [-7.5832e+17],
#         [-2.8034e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.6722e+08],
#         [-7.7349e+17],
#         [-2.8875e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.7689e+08],
#         [-7.8896e+17],
#         [-2.9741e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [ 3.6893e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.8666e+08],
#         [-8.0473e+17],
#         [-3.0633e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-9.9653e+08],
#         [-8.2083e+17],
#         [-3.1552e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0065e+09],
#         [-8.3725e+17],
#         [-3.2499e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0166e+09],
#         [-8.5399e+17],
#         [-3.3474e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0267e+09],
#         [-8.7107e+17],
#         [-3.4478e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0370e+09],
#         [-8.8849e+17],
#         [-3.5512e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [ 7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0474e+09],
#         [-9.0626e+17],
#         [-3.6577e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [ 7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0578e+09],
#         [-9.2439e+17],
#         [-3.7675e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0684e+09],
#         [-9.4287e+17],
#         [-3.8805e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0791e+09],
#         [-9.6173e+17],
#         [-3.9969e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.0899e+09],
#         [-9.8097e+17],
#         [-4.1168e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1008e+09],
#         [-1.0006e+18],
#         [-4.2403e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1118e+09],
#         [-1.0206e+18],
#         [-4.3675e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1229e+09],
#         [-1.0410e+18],
#         [-4.4986e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1341e+09],
#         [-1.0618e+18],
#         [-4.6335e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1455e+09],
#         [-1.0831e+18],
#         [-4.7725e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1569e+09],
#         [-1.1047e+18],
#         [-4.9157e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1685e+09],
#         [-1.1268e+18],
#         [-5.0632e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1802e+09],
#         [-1.1494e+18],
#         [-5.2151e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.1920e+09],
#         [-1.1723e+18],
#         [-5.3715e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2039e+09],
#         [-1.1958e+18],
#         [-5.5327e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-7.3787e+19]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2160e+09],
#         [-1.2197e+18],
#         [-5.6986e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2281e+09],
#         [-1.2441e+18],
#         [-5.8696e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2404e+09],
#         [-1.2690e+18],
#         [-6.0457e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2528e+09],
#         [-1.2944e+18],
#         [-6.2271e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2653e+09],
#         [-1.3203e+18],
#         [-6.4139e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2780e+09],
#         [-1.3467e+18],
#         [-6.6063e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.2908e+09],
#         [-1.3736e+18],
#         [-6.8045e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3037e+09],
#         [-1.4011e+18],
#         [-7.0086e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3167e+09],
#         [-1.4291e+18],
#         [-7.2189e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3299e+09],
#         [-1.4577e+18],
#         [-7.4354e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3432e+09],
#         [-1.4868e+18],
#         [-7.6585e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3566e+09],
#         [-1.5166e+18],
#         [-7.8883e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3702e+09],
#         [-1.5469e+18],
#         [-8.1249e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3839e+09],
#         [-1.5778e+18],
#         [-8.3687e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.3977e+09],
#         [-1.6094e+18],
#         [-8.6197e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4117e+09],
#         [-1.6416e+18],
#         [-8.8783e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4258e+09],
#         [-1.6744e+18],
#         [-9.1447e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4401e+09],
#         [-1.7079e+18],
#         [-9.4190e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4545e+09],
#         [-1.7420e+18],
#         [-9.7016e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4690e+09],
#         [-1.7769e+18],
#         [-9.9926e+26]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4837e+09],
#         [-1.8124e+18],
#         [-1.0292e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.4985e+09],
#         [-1.8487e+18],
#         [-1.0601e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.5135e+09],
#         [-1.8856e+18],
#         [-1.0919e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.5286e+09],
#         [-1.9234e+18],
#         [-1.1247e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-1.4757e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.5439e+09],
#         [-1.9618e+18],
#         [-1.1584e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.5594e+09],
#         [-2.0011e+18],
#         [-1.1932e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.5750e+09],
#         [-2.0411e+18],
#         [-1.2290e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.5907e+09],
#         [-2.0819e+18],
#         [-1.2658e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.6066e+09],
#         [-2.1235e+18],
#         [-1.3038e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.6227e+09],
#         [-2.1660e+18],
#         [-1.3429e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.6389e+09],
#         [-2.2093e+18],
#         [-1.3832e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.6553e+09],
#         [-2.2535e+18],
#         [-1.4247e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.6719e+09],
#         [-2.2986e+18],
#         [-1.4674e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.6886e+09],
#         [-2.3446e+18],
#         [-1.5115e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.7055e+09],
#         [-2.3915e+18],
#         [-1.5568e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[ -4.],
#         [ -8.],
#         [-12.]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.7225e+09],
#         [-2.4393e+18],
#         [-1.6035e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.7397e+09],
#         [-2.4881e+18],
#         [-1.6516e+27]], grad_fn=<AddBackward0>)
# grad_hypo :  tensor([[-4.0000e+00],
#         [-8.0000e+00],
#         [-2.9515e+20]], grad_fn=<MulBackward0>)
# grad_w :  tensor([[-1.7571e+09],
#         [-2.5378e+18],
#         [-1.7012e+27]], grad_fn=<AddBackward0>)
# Epoch 2000/2000 W: 584070550742662741909045248.000, b: -1752211799801940815403548672.000 Cost: inf

# %%
x_train = torch.FloatTensor([[1],[2],[3]])
y_train = torch.FloatTensor([[2],[4],[6]])

W = torch.zeros(1, requires_grad=True)
b = torch.zeros(1, requires_grad=True)

optimizer = optim.SGD([W, b], lr = 0.01)

epochs = 2000

for epoch in range(epochs + 1) :
    
    hypothesis = x_train * W + b
    
    cost = torch.mean((hypothesis - y_train) ** 2)
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
    # .item()으로 tensor 형식의 변수에서 값만 가져올 수 있음
    if epoch % 100 == 0 :
#         print(W)
#         print(b)
#         print(cost)
        print('Epoch {:4d}/{} W: {:.3f}, b: {:.3f} Cost: {:.6f}'.format(
            epoch, epochs, W.item(), b.item(), cost.item()))
# Out:
# Epoch    0/2000 W: 0.187, b: 0.080 Cost: 18.666666
# Epoch  100/2000 W: 1.746, b: 0.578 Cost: 0.048171
# Epoch  200/2000 W: 1.800, b: 0.454 Cost: 0.029767
# Epoch  300/2000 W: 1.843, b: 0.357 Cost: 0.018394
# Epoch  400/2000 W: 1.876, b: 0.281 Cost: 0.011366
# Epoch  500/2000 W: 1.903, b: 0.221 Cost: 0.007024
# Epoch  600/2000 W: 1.924, b: 0.174 Cost: 0.004340
# Epoch  700/2000 W: 1.940, b: 0.136 Cost: 0.002682
# Epoch  800/2000 W: 1.953, b: 0.107 Cost: 0.001657
# Epoch  900/2000 W: 1.963, b: 0.084 Cost: 0.001024
# Epoch 1000/2000 W: 1.971, b: 0.066 Cost: 0.000633
# Epoch 1100/2000 W: 1.977, b: 0.052 Cost: 0.000391
# Epoch 1200/2000 W: 1.982, b: 0.041 Cost: 0.000242
# Epoch 1300/2000 W: 1.986, b: 0.032 Cost: 0.000149
# Epoch 1400/2000 W: 1.989, b: 0.025 Cost: 0.000092
# Epoch 1500/2000 W: 1.991, b: 0.020 Cost: 0.000057
# Epoch 1600/2000 W: 1.993, b: 0.016 Cost: 0.000035
# Epoch 1700/2000 W: 1.995, b: 0.012 Cost: 0.000022
# Epoch 1800/2000 W: 1.996, b: 0.010 Cost: 0.000013
# Epoch 1900/2000 W: 1.997, b: 0.008 Cost: 0.000008
# Epoch 2000/2000 W: 1.997, b: 0.006 Cost: 0.000005

# %% [markdown]
# ## optimizer.zero_grad() 가 필요한 이유

# %% [markdown]
#     pytorch는 gradient를 loss.backward()를 통해서 계산하는데,
#     이 함수는 gradient를 덮어서 새로 계산하는 것이 아니라
#     이전 gradient에 누적하여 계산한다.
#
#     이렇게 누적해서 계산하는 이유는 RNN 모델을 구현 할 때 필요하기 때문이다.
#     그래서 RNN 모델이 아닌 다른 모델은 gradient를 누적 할 필요가 없기 때문에
#     model에 input을 통과 시키기전에 optimizer.zero_grad()를

# %% [markdown]
# ## .backward()가 어떤 것인지와 진행되는 방법
#
#     backpropagation과 같음.
